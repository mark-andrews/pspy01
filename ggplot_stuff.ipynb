# %%
import warnings
warnings.simplefilter('ignore')

# %%
from plotnine import ggplot, geom_point, aes, stat_smooth, facet_wrap, theme_classic
import pandas as pd

# %%
weight_df = pd.read_csv("weight.csv")

# %%
(ggplot(weight_df, aes('height', 'weight', color='gender'))
 + geom_point(size = 0.1) + theme_classic() + facet_wrap('~ handedness'))
# Out:
# <ggplot: (8728731604313)>
